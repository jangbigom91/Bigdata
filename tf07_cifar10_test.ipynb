# %% [markdown]
# <a href="https://colab.research.google.com/github/jangbigom91/Bigdata/blob/master/tf07_cifar10_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2020/08/19
이름 : 최정한
내용 : 딥러닝 cifar10 이미지 분류 실습하기
"""

import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.datasets.cifar10 import load_data
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from sklearn.model_selection import train_test_split
from PIL import Image #파이썬 이미지 처리 라이브러리

# %%
#학습데이터 로드
(cifar_train_data, cifar_train_label), (cifar_test_data, cifar_test_label) = load_data()

#데이터 형태 확인
print(cifar_train_data.shape, cifar_train_label.shape)
print(cifar_test_data.shape, cifar_test_label.shape)
print(cifar_train_label)
# Out:
# (50000, 32, 32, 3) (50000, 1)
# (10000, 32, 32, 3) (10000, 1)
# [[6]
#  [9]
#  [9]
#  ...
#  [9]
#  [1]
#  [1]]

# %%
#데이터 샘플 이미지 출력
class_names = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer', 'Dog', 'Frog', 'Horse', 'Ship', 'Truck']
random_idx = np.random.randint(50000, size=9)
print(random_idx)

plt.figure(figsize=(5, 5))

for i, idx in enumerate(random_idx):
  plt.subplot(3, 3, i+1)
  plt.xticks([])
  plt.yticks([])
  label = cifar_train_label[idx][0]
  plt.imshow(cifar_train_data[idx, :])
  plt.title('%s' % class_names[label])
# Out:
# [12603 46095  1066 44553 48884 34575 27048 17432 48124]

# %%
#데이터셋 분할하기
train_data, test_data, train_label, test_label = train_test_split(cifar_train_data, cifar_train_label)
print('훈련 데이터 : ', train_data.shape)
print('검증 데이터 : ', test_data.shape)
# Out:
# 훈련 데이터 :  (37500, 32, 32, 3)
# 검증 데이터 :  (12500, 32, 32, 3)

# %%
#모델학습을 위한 데이터 전처리(정규화)

#방법1 : 픽셀데이터를 0 ~ 1 사이로 초기화 -> 정확도 낮음
#train_data = train_data / 255
#test_data = test_data / 255
#mnist_test_data = mnist_test_data / 255

#방법2 : 픽셀데이터를 평균과 표준편차를 이용한 정규화 -> 정확도 높음
mean = np.mean(train_data, axis=(0, 1, 2))
std = np.std(train_data, axis=(0, 1, 2))

train_data = (train_data - mean) / std
test_data = (test_data - mean) / std
cifar_test_data = (cifar_test_data - mean) / std


#각 데이터의 레이블을 범주형(One-hot encoding) 형태로 변환
train_label = to_categorical(train_label)
test_label = to_categorical(test_label)
cifar_test_label = to_categorical(cifar_test_label)

# %%
#학습 모델 구성하기
model = Sequential()
model.add(Flatten(input_shape=(32, 32, 3))) #입력층
model.add(Dense(64, activation='relu'))  #은닉층
model.add(Dense(32, activation='relu'))  #은닉층
model.add(Dense(10, activation='softmax')) #출력층

# %%
#학습모델 선정하기
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

# %%
#학습하기
model.fit(train_data,
          train_label,
          epochs=30,
          batch_size=128,
          validation_data=(test_data, test_label))
# Out:
# Epoch 1/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.8391 - acc: 0.3620 - val_loss: 1.6863 - val_acc: 0.4198
# Epoch 2/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.6127 - acc: 0.4370 - val_loss: 1.6234 - val_acc: 0.4425
# Epoch 3/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.5051 - acc: 0.4693 - val_loss: 1.5714 - val_acc: 0.4569
# Epoch 4/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.4368 - acc: 0.4990 - val_loss: 1.5473 - val_acc: 0.4662
# Epoch 5/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.3851 - acc: 0.5136 - val_loss: 1.5171 - val_acc: 0.4768
# Epoch 6/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.3403 - acc: 0.5292 - val_loss: 1.5227 - val_acc: 0.4741
# Epoch 7/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.3010 - acc: 0.5442 - val_loss: 1.5280 - val_acc: 0.4738
# Epoch 8/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.2639 - acc: 0.5561 - val_loss: 1.5419 - val_acc: 0.4732
# Epoch 9/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.2357 - acc: 0.5642 - val_loss: 1.5277 - val_acc: 0.4804
# Epoch 10/30
# 293/293 [==============================] - 2s 5ms/step - loss: 1.2065 - acc: 0.5738 - val_loss: 1.5225 - val_acc: 0.4804
# Epoch 11/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.1750 - acc: 0.5856 - val_loss: 1.5141 - val_acc: 0.4817
# Epoch 12/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.1551 - acc: 0.5921 - val_loss: 1.5441 - val_acc: 0.4882
# Epoch 13/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.1304 - acc: 0.5991 - val_loss: 1.5167 - val_acc: 0.4911
# Epoch 14/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.1057 - acc: 0.6078 - val_loss: 1.5593 - val_acc: 0.4848
# Epoch 15/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.0819 - acc: 0.6170 - val_loss: 1.5604 - val_acc: 0.4822
# Epoch 16/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.0688 - acc: 0.6219 - val_loss: 1.5755 - val_acc: 0.4843
# Epoch 17/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.0569 - acc: 0.6280 - val_loss: 1.5746 - val_acc: 0.4855
# Epoch 18/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.0302 - acc: 0.6345 - val_loss: 1.6165 - val_acc: 0.4782
# Epoch 19/30
# 293/293 [==============================] - 2s 6ms/step - loss: 1.0222 - acc: 0.6372 - val_loss: 1.6050 - val_acc: 0.4846
# Epoch 20/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.9998 - acc: 0.6477 - val_loss: 1.6474 - val_acc: 0.4734
# Epoch 21/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.9809 - acc: 0.6517 - val_loss: 1.6463 - val_acc: 0.4787
# Epoch 22/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.9669 - acc: 0.6589 - val_loss: 1.6742 - val_acc: 0.4763
# Epoch 23/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.9529 - acc: 0.6597 - val_loss: 1.6523 - val_acc: 0.4835
# Epoch 24/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.9411 - acc: 0.6644 - val_loss: 1.6828 - val_acc: 0.4857
# Epoch 25/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.9300 - acc: 0.6723 - val_loss: 1.6940 - val_acc: 0.4815
# Epoch 26/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.9159 - acc: 0.6763 - val_loss: 1.7218 - val_acc: 0.4758
# Epoch 27/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.9001 - acc: 0.6825 - val_loss: 1.7290 - val_acc: 0.4780
# Epoch 28/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.8874 - acc: 0.6861 - val_loss: 1.7893 - val_acc: 0.4682
# Epoch 29/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.8792 - acc: 0.6887 - val_loss: 1.8136 - val_acc: 0.4683
# Epoch 30/30
# 293/293 [==============================] - 2s 6ms/step - loss: 0.8682 - acc: 0.6905 - val_loss: 1.7572 - val_acc: 0.4778

# %%
#평가하기
model.evaluate(cifar_test_data, cifar_test_label)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 1.7452 - acc: 0.4834
# [1.7452187538146973, 0.48339998722076416]

# %%
#테스트하기
result = model.predict(cifar_test_data)

from sklearn.metrics import accuracy_score
score = accuracy_score(result.round(), cifar_test_label)
print('점수 : ', score)
# Out:
# 점수 :  0.393
